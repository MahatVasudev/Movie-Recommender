# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir("E:/Internship/data/")

# %% [markdown]
# # Code

# %%
movies = pd.read_csv('./movies_v6.csv',sep="\t")
# Out:
# C:\Users\mahat\AppData\Local\Temp\ipykernel_28644\762535217.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('./movies_v6.csv',sep="\t")

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'adult', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count',
#        'release_year', 'new title', 'overview_cleaned', 'critically_acclaimed',
#        'age_rating', 'poster_done', 'poster_link', 'new_spoken_languages',
#        'new_production_companies', 'production_countries',
#        'new_production_countries'],
#       dtype='object')

# %%
movies_dup = movies.copy(deep=True)

# %%
movies.drop(['Unnamed: 0',"adult","belongs_to_collection",
             "genres","homepage","poster_path",
             "production_companies","status","video","spoken_languages",
             "poster_done","production_countries"],axis=1,inplace=True)

# %%
movies
# Out:
#          budget      id    imdb_id original_language  \
# 0      30000000     862  tt0114709                en
# 1      65000000    8844  tt0113497                en
# 2             0   15602  tt0113228                en
# 3      16000000   31357  tt0114885                en
# 4             0   11862  tt0113041                en
# ...         ...     ...        ...               ...
# 45407         0  439050  tt6209470                fa
# 45408         0  111109  tt2028550                tl
# 45409         0   67758  tt0303758                en
# 45410         0  227506  tt0008536                en
# 45411         0  461257  tt6980792                en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45407                      رگ خواب
# ...

# %%
movies.rename({"new_spoken_languages":"spoken_languages",
               "new_production_companies":"production_companies",
               "new_production_countries":"production_countries",
              "new title":"new_title","release_year":"year","critically_acclaimed":"critical_score"},axis=1, inplace=1)

# %%
movies.columns
# Out:
# Index(['budget', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'release_date', 'revenue', 'runtime',
#        'tagline', 'title', 'vote_average', 'vote_count', 'year', 'new_title',
#        'overview_cleaned', 'critical_score', 'age_rating', 'poster_link',
#        'spoken_languages', 'production_companies', 'production_countries'],
#       dtype='object')

# %%
movies = movies[['id','original_title','title','new_title',
                 'imdb_id',
                 'budget','revenue',
                "year","runtime","release_date","age_rating","vote_average","vote_count","popularity","critical_score"]]

# %%
movies_dup
# Out:
#        Unnamed: 0  adult                              belongs_to_collection  \
# 0               0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1               1  False                                                N/R
# 2               2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3               3  False                                                N/R
# 4               4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...           ...    ...                                                ...
# 45407       45407  False                                                N/R
# 45408       45408  False                                                N/R
# 45409       45409  False                                                N/R
# 45410       45410  False                                                N/R
# 45411       45411  False                                                N/R
#
# ...

# %%
movies = movies[['id','original_title','title','new_title',
                 'imdb_id', 'overview','overview_cleaned',
                 'budget','revenue','tagline','spoken_languages',
                'original_language',
                "year","release_date","age_rating","vote_average","vote_count","critical_score","poster_link",
                 "popularity","runtime","production_companies","production_countries"]]

# %%
movies['runtime'] = movies['runtime'].fillna(0)

# %%
movies[movies['runtime'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, original_title, title, new_title, imdb_id, overview, overview_cleaned, budget, revenue, tagline, spoken_languages, original_language, year, release_date, age_rating, vote_average, vote_count, critical_score, poster_link, popularity, runtime, production_companies, production_countries]
# Index: []

# %%
movies_descript = movies_dup.copy(deep=True)

# %%
movies_descript.drop(['Unnamed: 0',"adult","belongs_to_collection",
             "genres","homepage","poster_path",
             "production_companies","status","video","spoken_languages",
             "poster_done","production_countries"],axis=1,inplace=True)

movies_descript.rename({"new_spoken_languages":"spoken_languages",
               "new_production_companies":"production_companies",
               "new_production_countries":"production_countries",
              "new title":"new_title","release_year":"year","critically_acclaimed":"critical_score"},axis=1, inplace=1)

# %%
movies_descript = movies_descript[['id','overview','overview_cleaned',
                          'tagline','spoken_languages','original_language',"poster_link","production_companies","production_countries"]]

# %%
movies_descript.drop_duplicates(subset="id",inplace=True)

# %%
movies_descript.to_csv("movies_descritp_final.csv",sep='\t',index=False)

# %%
movies_descript
# Out:
#            id                                           overview  \
# 0         862  Led by Woody, Andy's toys live happily in his ...
# 1        8844  When siblings Judy and Peter discover an encha...
# 2       15602  A family wedding reignites the ancient feud be...
# 3       31357  Cheated on, mistreated and stepped on, the wom...
# 4       11862  Just when George Banks has recovered from his ...
# ...       ...                                                ...
# 45407  439050        Rising and falling between a man and woman.
# 45408  111109  An artist struggles to finish his work while a...
# 45409   67758  When one of her hits goes wrong, a professiona...
# 45410  227506  In a small town live two brothers, one a minis...
# 45411  461257  50 years after decriminalisation of homosexual...
#
#                                         overview_cleaned  \
# 0      led woody, andi toy live happili room andi bir...
# 1      sibl judi peter discov enchant board game open...
# ...

# %%
movies[movies['id'].duplicated(keep='last')]
# Out:
#            id                   original_title  \
# 838    132641                            Tsuma
# 949     22649               A Farewell to Arms
# 2563    84198             A Place at the Table
# 4113    10991             Pokémon 3: The Movie
# 4355   110428             Camille Claudel 1915
# 5129    15028                    Clockstoppers
# 5534    12600   劇場版ポケットモンスター セレビィ 時を越えた遭遇（であい）
# 5709   109962                  Rich and Famous
# 5864     4912  Confessions of a Dangerous Mind
# 9573    69234         The Phantom of the Opera
# 10416   14788                           Bubble
# 11152   77221                       Black Gold
# 11339   13209                          Offside
#
#                                              title  \
# 838                                           Wife
# 949                             A Farewell to Arms
# 2563                          A Place at the Table
# 4113                 Pokémon: Spell of the Unknown
# ...

# %%
movies.drop_duplicates(subset='id',inplace=True)

# %%
movies.to_csv("movies_final.csv",sep="\t",index=False)

# %%
movies.at[0,"original_language"]
# Out:
# 'en'

# %%
len(movies.columns)
# Out:
# 24

# %%
movies_check = pd.read_csv("./movies_final.csv",sep="\t")

# %%
movies_check[movies_check['id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, original_title, title, new_title, imdb_id, overview, overview_cleaned, budget, revenue, tagline, spoken_languages, original_language, year, release_date, age_rating, vote_average, vote_count, critical_score, poster_link, popularity, runtime, production_companies, production_countries]
# Index: []

# %%
len(movies_check.loc[7240,"original_title"])
# Out:
# 104

# %%
pd.options.display.max_columns = None
movies_check
# Out:
#            id               original_title                        title  \
# 0         862                    Toy Story                    Toy Story
# 1        8844                      Jumanji                      Jumanji
# 2       15602             Grumpier Old Men             Grumpier Old Men
# 3       31357            Waiting to Exhale            Waiting to Exhale
# 4       11862  Father of the Bride Part II  Father of the Bride Part II
# ...       ...                          ...                          ...
# 45407  439050                      رگ خواب                       Subdue
# 45408  111109          Siglo ng Pagluluwal          Century of Birthing
# 45409   67758                     Betrayal                     Betrayal
# 45410  227506          Satana likuyushchiy             Satan Triumphant
# 45411  461257                     Queerama                     Queerama
#
#                                 new_title    imdb_id  \
# ...

# %%
ratings = pd.read_csv("ratings_cleaned_v1.csv", sep="\t")

# %%
index = movies[movies['id']==5].index[0]
movies.at[index,"new_title"]
# Out:
# 'Four Rooms (1995)'

# %%
f"{len(ratings):,}"
# Out:
# '11,436,562'

# %%
ratings[ratings['userId'] == 2]['rating']
# Out:
# 0     1.0
# 1     4.5
# 2     5.0
# 3     5.0
# 4     4.0
# 5     4.5
# 6     4.0
# 7     4.0
# 8     3.5
# 9     4.0
# 10    5.0
# Name: rating, dtype: float64

# %%
for rating in ratings:
    print(rating)
# Out:
# userId
# movieId
# rating
# timestamp
# date_time
