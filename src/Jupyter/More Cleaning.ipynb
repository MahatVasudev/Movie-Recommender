# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Code

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_csv('./data/movies_cleaned.csv')

# %%
df.head()
# Out:
#    adult belongs_to_collection    budget  \
# 0  False                   N/R  30000000
# 1  False                   N/R  65000000
# 2  False                   N/R         0
# 3  False                   N/R  16000000
# 4  False                   N/R         0
#
#                                               genres homepage     id  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      N/R    862
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      N/R   8844
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      N/R  15602
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      N/R  31357
# 4                     [{'id': 35, 'name': 'Comedy'}]      N/R  11862
#
#      imdb_id original_language               original_title overview  \
# 0  tt0114709                en                    Toy Story      N/R
# 1  tt0113497                en                      Jumanji      N/R
# 2  tt0113228                en             Grumpier Old Men      N/R
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45460 entries, 0 to 45459
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45460 non-null  bool
#  1   belongs_to_collection  45460 non-null  object
#  2   budget                 45460 non-null  int64
#  3   genres                 45460 non-null  object
#  4   homepage               45460 non-null  object
#  5   id                     45460 non-null  int64
#  6   imdb_id                45443 non-null  object
#  7   original_language      45449 non-null  object
#  8   original_title         45460 non-null  object
#  9   overview               45460 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45460 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
df.describe()
# Out:
#              budget            id    popularity       revenue       runtime  \
# count  4.546000e+04   45460.00000  45460.000000  4.546000e+04  45203.000000
# mean   4.224858e+06  108357.07004      2.921478  1.120935e+07     94.128199
# std    1.742467e+07  112462.43383      6.005414  6.433225e+07     38.407810
# min    0.000000e+00       2.00000      0.000000  0.000000e+00      0.000000
# 25%    0.000000e+00   26448.50000      0.385948  0.000000e+00     85.000000
# 50%    0.000000e+00   59999.00000      1.127685  0.000000e+00     95.000000
# 75%    0.000000e+00  157324.00000      3.678902  0.000000e+00    107.000000
# max    3.800000e+08  469172.00000    547.488298  2.787965e+09   1256.000000
#
#        vote_average    vote_count  release_year
# count  45460.000000  45460.000000  45376.000000
# mean       5.618207    109.897338   1991.881193
# std        1.924216    491.310374     24.055360
# min        0.000000      0.000000   1874.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  adult    budget        id  popularity   revenue   runtime  \
# adult         1.000000 -0.003345  0.007286   -0.003392 -0.002452 -0.009029
# budget       -0.003345  1.000000 -0.101667    0.449645  0.768776  0.134733
# id            0.007286 -0.101667  1.000000   -0.083474 -0.071263 -0.121399
# popularity   -0.003392  0.449645 -0.083474    1.000000  0.506179  0.129927
# revenue      -0.002452  0.768776 -0.071263    0.506179  1.000000  0.103917
# runtime      -0.009029  0.134733 -0.121399    0.129927  0.103917  1.000000
# video        -0.000637 -0.010831  0.041576   -0.015574 -0.007889 -0.010733
# vote_average -0.012403  0.073494 -0.167573    0.154399  0.083868  0.158146
# vote_count   -0.002922  0.676642 -0.064903    0.559965  0.812022  0.113539
# release_year  0.004413  0.131675  0.286896    0.131690  0.088355  0.078822
#
#                  video  vote_average  vote_count  release_year
# adult        -0.000637     -0.012403   -0.002922      0.004413
# ...

# %%
sns.scatterplot(x = df['popularity'],y =df['revenue'],)
# Out:
# <Axes: xlabel='popularity', ylabel='revenue'>

# %%
sns.scatterplot(x = df['popularity'],y =df['adult'],)
# Out:
# <Axes: xlabel='popularity', ylabel='adult'>

# %%
sns.scatterplot(x = df['popularity'],y =df['adult'],)

# %%
production_company_budget = df.groupby(['production_companies'])['budget'].sum().head(10).reset_index().sort_values('budget',ascending=False)

# %%
production_company_revenue = df.groupby(['production_companies'])['revenue'].sum().head(10).reset_index().sort_values('revenue',ascending=False)

# %%
production_company_revenue
# Out:
#                                 production_companies       revenue
# 0                                                 []  1.703071e+09
# 9  [{'name': "Cast N' Crew", 'id': 79808}, {'name...  2.300000e+06
# 1  [{'name': "'A' Production Committee", 'id': 44...  0.000000e+00
# 2       [{'name': "Ali'n Productions", 'id': 58725}]  0.000000e+00
# 3  [{'name': "Anarchist's Convention Films", 'id'...  0.000000e+00
# 4           [{'name': "Archer's Mark", 'id': 30601}]  0.000000e+00
# 5  [{'name': "BTV Kaku Children's Satellite TV", ...  0.000000e+00
# 6  [{'name': "Boyd's Company", 'id': 3147}, {'nam...  0.000000e+00
# 7  [{'name': "Butcher's Run Films", 'id': 3864}, ...  0.000000e+00
# 8  [{'name': "Butcher's Run Productions", 'id': 1...  0.000000e+00

# %% [markdown]
# ## By this we understand the there is lack of data about the production companies involved on movies

# %%
import json

# %%
df[df['production_companies'] == json.dumps([])].shape[0]
# Out:
# 11875

# %% [markdown]
# - There is in total **11875** production companies data missing.

# %%
df[df['production_countries'] == json.dumps([])].shape[0]
# Out:
# 6282

# %% [markdown]
# - There is in total **6282** production countries data missing.
